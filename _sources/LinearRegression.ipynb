# %% [markdown]
# ##Linear Regression##

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
x_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(x_test, y_test)
reg.score(x_test, y_test)

reg.coef_

reg.intercept_

#reg.predict(np.array([[3]]))
# Out:
# -1.713614290950157

# %%
pyplot.scatter(x_test, y_test)
pyplot.show()

# %%
training_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3cd7efa658f1> in <module>
# ----> 1 training_label
#
# NameError: name 'training_label' is not defined

# %%
pyplot.scatter(x_test, y_test)
Y_plot = reg.coef_*X_test+reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-06fb242cc5cb> in <module>
#       1 pyplot.scatter(x_test, y_test)
# ----> 2 Y_plot = reg.coef_*X_test+reg.intercept_
#
# NameError: name 'X_test' is not defined

# %%
reg.coef_

# %%
reg.intercept_

# %%
reg.predict(np.array([[2]]))
